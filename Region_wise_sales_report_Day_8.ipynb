# %% [markdown]
# <a href="https://colab.research.google.com/github/madhumithamadasamy/DataAnalytics-Using-Python-Project/blob/main/Region_wise_sales_report_Day_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {
    "Region": ["North", "South", "East", "West", "North", "South"],
    "Product": ["Laptop", "Mobile", "Tablet", "Laptop", "Mobile", "Tablet"],
    "Sales": [5000, 7000, 4500, 6000, 8000, 5500]
}

df = pd.DataFrame(data)

print("Sales Data:")
print(df)

print("\nTotal Sales by Region:")
Region_sales = df.groupby("Region")["Sales"].sum()
print(Region_sales)


high_sales=df[df["Sales"]>30000]
print(high_sales)

sorted_df=df.sort_values("Sales")
print(sorted_df)

result = df.groupby("Region")["Sales"].agg(
    ["sum", "mean", "max", "min", "count"]
)
print(result)
# Out:
# Sales Data:
#   Region Product  Sales
# 0  North  Laptop   5000
# 1  South  Mobile   7000
# 2   East  Tablet   4500
# 3   West  Laptop   6000
# 4  North  Mobile   8000
# 5  South  Tablet   5500
#
# Total Sales by Region:
# Region
# East      4500
# North    13000
# South    12500
# West      6000
# Name: Sales, dtype: int64
# Empty DataFrame
# Columns: [Region, Product, Sales]
# Index: []
#   Region Product  Sales
# 2   East  Tablet   4500
# 0  North  Laptop   5000
# 5  South  Tablet   5500
# 3   West  Laptop   6000
# 1  South  Mobile   7000
# 4  North  Mobile   8000
#           sum    mean   max   min  count
# Region
# East     4500  4500.0  4500  4500      1
# North   13000  6500.0  8000  5000      2
# South   12500  6250.0  7000  5500      2
# West     6000  6000.0  6000  6000      1
