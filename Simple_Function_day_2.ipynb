# %% [markdown]
# <a href="https://colab.research.google.com/github/madhumithamadasamy/DataAnalytics-Using-Python-Project/blob/main/Simple_Function_day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet():
  print("Hi Internship students")
greet()
# Out:
# Hi Internship students

# %%
def greet(name):
  print("Welcome", name)
greet("Madhu")
# Out:
# Welcome Madhu

# %%
def add(a,b):
  return a+b
result = add(10,20)
print(result)
# Out:
# 30
