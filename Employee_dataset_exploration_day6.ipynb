# %% [markdown]
# <a href="https://colab.research.google.com/github/madhumithamadasamy/DataAnalytics-Using-Python-Project/blob/main/Employee_dataset_exploration_day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
employees =  {
    "Emp_Id": [101,102,103,104,105],
    "Name": ["Priya","Moni","Maha","Madhu","Kavi"],
    "Department": ["IT","HR","IT","Finance","HR"],
    "Salary": [45000,40000,50000,55000,42000],
    "Experience": [2,3,5,6,4]
}
df = pd.DataFrame(employees)

print("Employee Dataset")
print(df)

print("\nAverage Salary")
print(df["Salary"].mean())

print("\nHighest Salary")
print(df["Salary"].max())

print("\nEmployee in HR")
print(df[df["Department"]=="HR"])

print("\nEmployee with Experience")
print(df[df["Experience"]>3])

print("\nEmployee Count by Department")
print(df["Department"].value_counts())
# Out:
# Employee Dataset
#    Emp_Id   Name Department  Salary  Experience
# 0     101  Priya         IT   45000           2
# 1     102   Moni         HR   40000           3
# 2     103   Maha         IT   50000           5
# 3     104  Madhu    Finance   55000           6
# 4     105   Kavi         HR   42000           4
#
# Average Salary
# 46400.0
#
# Highest Salary
# 55000
#
# Employee in HR
#    Emp_Id  Name Department  Salary  Experience
# 1     102  Moni         HR   40000           3
# 4     105  Kavi         HR   42000           4
#
# Employee with Experience
#    Emp_Id   Name Department  Salary  Experience
# 2     103   Maha         IT   50000           5
# 3     104  Madhu    Finance   55000           6
# 4     105   Kavi         HR   42000           4
#
# Employee Count by Department
# Department
# IT         2
# HR         2
# Finance    1
# Name: count, dtype: int64
