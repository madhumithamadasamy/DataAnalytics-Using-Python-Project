# %% [markdown]
# <a href="https://colab.research.google.com/github/madhumithamadasamy/DataAnalytics-Using-Python-Project/blob/main/Mini_project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **E-commerce Sales Analysis**

# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt

uploaded = files.upload()

df = pd.read_csv("sales_data_250_records.csv")
print(df)
# Out:
#      <input type="file" id="files-15d88513-e7b8-4fdf-a025-66d8de42dcdc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15d88513-e7b8-4fdf-a025-66d8de42dcdc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head(20)
# Out:
#     Order_ID  Order_Date Customer_Name Region           State     Category  \
# 0       1001  2025-11-24         Meena  South       Karnataka  Electronics
# 1       1002  2025-10-30         Nisha  South      Tamil Nadu  Electronics
# 2       1003  2025-10-15        Suresh   West     Maharashtra     Clothing
# 3       1004  2025-03-23         Nisha   East           Assam  Electronics
# 4       1005  2025-02-19         Deepa   East           Assam      Grocery
# 5       1006  2025-02-10         Pooja   East           Assam    Furniture
# 6       1007  2025-05-29          Arun  North           Delhi     Clothing
# 7       1008  2025-03-25         Deepa   East          Odisha    Furniture
# 8       1009  2025-10-01        Anitha  North          Punjab     Clothing
# 9       1010  2025-04-28         Priya   East           Bihar  Electronics
# 10      1011  2025-04-19         Sneha   West             NaN     Clothing
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       252 non-null    int64
#  1   Order_Date     252 non-null    object
#  2   Customer_Name  251 non-null    object
#  3   Region         252 non-null    object
#  4   State          251 non-null    object
#  5   Category       252 non-null    object
#  6   Product        252 non-null    object
#  7   Quantity       252 non-null    int64
#  8   Unit_Price     252 non-null    int64
#  9   Discount       252 non-null    int64
#  10  Sales          252 non-null    float64
#  11  Profit         252 non-null    float64
#  12  Payment_Mode   252 non-null    object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 25.7+ KB
# None

# %%
print(df.shape)
# Out:
# (252, 13)

# %%
print(df.isnull().sum())
# Out:
# Order_ID         0
# Order_Date       0
# Customer_Name    1
# Region           0
# State            1
# Category         0
# Product          0
# Quantity         0
# Unit_Price       0
# Discount         0
# Sales            0
# Profit           0
# Payment_Mode     0
# dtype: int64

# %%
df = df.drop_duplicates()
print(df)
# Out:
#      Order_ID  Order_Date Customer_Name Region           State     Category  \
# 0        1001  2025-11-24         Meena  South       Karnataka  Electronics
# 1        1002  2025-10-30         Nisha  South      Tamil Nadu  Electronics
# 2        1003  2025-10-15        Suresh   West     Maharashtra     Clothing
# 3        1004  2025-03-23         Nisha   East           Assam  Electronics
# 4        1005  2025-02-19         Deepa   East           Assam      Grocery
# ..        ...         ...           ...    ...             ...          ...
# 245      1246  2025-07-08       Lavanya  North           Delhi  Electronics
# 246      1247  2025-08-01         Pooja   West       Rajasthan      Grocery
# 247      1248  2025-09-27         Manoj   East     West Bengal    Furniture
# 248      1249  2025-10-21         Pooja  North           Delhi     Clothing
# 249      1250  2025-10-26         Sneha  South  Andhra Pradesh      Grocery
#
# ...

# %%
total_sales = df['Sales'].sum()
print("Total Sales:",total_sales)
# Out:
# Total Sales: 12011009.0

# %%
product_sales = df.groupby('Product')['Sales'].sum()
print(product_sales)
# Out:
# Product
# Chair           297325.0
# Headphones      190260.0
# Jeans           138450.0
# Laptop         3063500.0
# Mobile         2577300.0
# Oil              17784.0
# Rice              4131.0
# Shirt            93690.0
# Smart Watch     482625.0
# Sofa           2571250.0
# Sugar             2979.0
# T-Shirt          40215.0
# Table          1181500.0
# Tablet         1350000.0
# Name: Sales, dtype: float64

# %%
product_sales.plot(kind='bar')
plt.xlabel('Product')
plt.ylabel('Sales')
plt.title('Product Sales Analysis')
plt.show()
