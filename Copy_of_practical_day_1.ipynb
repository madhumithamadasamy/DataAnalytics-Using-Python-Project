# %% [markdown]
# <a href="https://colab.research.google.com/github/madhumithamadasamy/DataAnalytics-Using-Python-Project/blob/main/Copy_of_practical_day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mark1 = int(input("Enter marks for subject 1:"))
mark2 = int(input("Enter marks for subject 2:"))
mark3 = int(input("Enter marks for subject 3:"))

total = mark1 + mark2 + mark3
Average = total/3

print("Total marks =",total)
print("Average marks =",Average)

if Average >= 50:
  print("Pass")
else:
  print("Fail")
# Out:
# Enter marks for subject 1:30
# Enter marks for subject 2:80
# Enter marks for subject 3:60
# Total marks = 170
# Average marks = 56.666666666666664
# Pass
