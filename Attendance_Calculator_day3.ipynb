# %% [markdown]
# <a href="https://colab.research.google.com/github/madhumithamadasamy/DataAnalytics-Using-Python-Project/blob/main/Attendance_Calculator_day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def attendance_percentage(attended, total):
    percentage = (attended / total) * 100
    return round(percentage, 2)

def check_eligibility(percent):
    if percent >= 75:
        return "ELIGIBLE"
    else:
        return "NOT ELIGIBLE"

try:
    total = int(input("Total Classes: "))
    attended = int(input("Classes Attended: "))

    pct = attendance_percentage(attended, total)
    status = check_eligibility(pct)

    print(f"Attendance: {pct}%")
    print(f"Status: {status}")

except ValueError:
    print("Enter valid numbers")
# Out:
# Total Classes: 70
# Classes Attended: 65
# Attendance: 92.86%
# Status: ELIGIBLE
