# %% [markdown]
# <a href="https://colab.research.google.com/github/madhumithamadasamy/DataAnalytics-Using-Python-Project/blob/main/day3_slicing_and_indexing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#indexing
import numpy as np
marks=np.array([90,85,78,92])
print(marks[2])
# Out:
# 78

# %%
# slicing concept
import numpy as np
marks=np.array([90,85,78,92])
print(marks[1:4])
# Out:
# [85 78 92]
