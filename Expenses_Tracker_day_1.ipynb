# %% [markdown]
# <a href="https://colab.research.google.com/github/madhumithamadasamy/DataAnalytics-Using-Python-Project/blob/main/Expenses_Tracker_day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Expenses = [100, 250, 300, 150]

Total = sum(Expenses)

print("Expenses:",Expenses)
print("Total Expenses:", Total)
# Out:
# Expenses: [100, 250, 300, 150]
# Total Expenses: 800
